# %% [markdown]
# # ☔ Flood Prediction Dataset using Linear Regression ☔
# My name is Queen Maegan R. Pedido from COM231 and this is my take on Kaggle's 'Regression with a Flood Prediction' for my midterm exam.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Read Dataset

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/train.csv?raw=true'
train_data = pd.read_csv(dataset_url)
train_data.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %% [markdown]
# # Data Training

# %%
train_data.shape
# Out:
# (1117957, 22)

# %%
train_data.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
train_data.isna().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
train_data.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.117957e+06      1.117957e+06        1.117957e+06     1.117957e+06
# mean   5.589780e+05      4.921450e+00        4.926671e+00     4.955322e+00
# std    3.227265e+05      2.056387e+00        2.093879e+00     2.072186e+00
# min    0.000000e+00      0.000000e+00        0.000000e+00     0.000000e+00
# 25%    2.794890e+05      3.000000e+00        3.000000e+00     4.000000e+00
# 50%    5.589780e+05      5.000000e+00        5.000000e+00     5.000000e+00
# 75%    8.384670e+05      6.000000e+00        6.000000e+00     6.000000e+00
# max    1.117956e+06      1.600000e+01        1.800000e+01     1.600000e+01
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.117957e+06  1.117957e+06   1.117957e+06  1.117957e+06  1.117957e+06
# mean    4.942240e+00  4.942517e+00   4.934093e+00  4.955878e+00  4.927791e+00
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117957 entries, 0 to 1117956
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id                               1117957 non-null  int64
#  1   MonsoonIntensity                 1117957 non-null  int64
#  2   TopographyDrainage               1117957 non-null  int64
#  3   RiverManagement                  1117957 non-null  int64
#  4   Deforestation                    1117957 non-null  int64
#  5   Urbanization                     1117957 non-null  int64
#  6   ClimateChange                    1117957 non-null  int64
#  7   DamsQuality                      1117957 non-null  int64
#  8   Siltation                        1117957 non-null  int64
#  9   AgriculturalPractices            1117957 non-null  int64
#  10  Encroachments                    1117957 non-null  int64
# ...

# %%
train_data.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
# ...

# %%
X = train_data.drop(['id', 'FloodProbability'], axis=1) #features
y = train_data[['FloodProbability']] #target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.85,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
m = lr.coef_[0]
m = m[0]

# Intercept
b = lr.intercept_[0]

print("b = ", b)
print("m = ", m)
print("y = ", m, "* x + ", b)
# Out:
# b =  -0.05343423102605527
# m =  0.005616746195154408
# y =  0.005616746195154408 * x +  -0.05343423102605527

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Scatterplot
# This scatterplot shows the relationship between the actual flood probabilities (y_test) and the flood probabilities predicted the linear regression model (y_pred).

# %%
plt.scatter(y_test, y_pred, color = 'blue', label='Actual vs Predicted')

plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=3, label='Ideal Prediction')

plt.title('Actual vs Predicted Flood Probability')
plt.xlabel('Actual Flood Probability')
plt.ylabel('Predicted Flood Probability')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Distribution Graph
# These graphs show the distribution of values for each feature in the training dataset.

# %%
nrows = (len(train_data.columns) + 2) // 3
ncols = min(len(train_data.columns), 3)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 5 * nrows))

if nrows == 1:
    axes = [axes]
elif ncols > 1:
    axes = axes.flatten()


for i, col in enumerate(train_data.columns):
    if col in ['id', 'FloodProbability']:
        continue

    ax = axes[i]
    sns.histplot(train_data[col],bins=40, kde=True, ax=ax)
    ax.set_title(col + ' Distribution')
    ax.set_ylabel('Frequency')
    ax.set_xlabel(col)

features_to_plot = [col for col in train_data.columns if col not in ['id', 'FloodProbability']]
if nrows * ncols > len(features_to_plot):
    for i in range(len(features_to_plot), nrows * ncols):
        fig.delaxes(axes[i])

plt.tight_layout()
plt.show();

# %% [markdown]
# ## Heatmap
# This heatmap visualizes the linear correlation coefficients between all pairs of features and the target variable FloodProbability.

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(train_data.corr(), annot=True,fmt='.2f', cmap='coolwarm', vmax=1, vmin=-1)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.title("Correlation Heatmap")
plt.show()
;
# Out:
# ''

# %% [markdown]
# # Accuracy of Model

# %%
pred_lr = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8445016495570807

# %% [markdown]
# # Test Data

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/test.csv?raw=true'
testdata = pd.read_csv(test_url)

# %% [markdown]
# # Read Test Dataset

# %%
testdata.shape
# Out:
# (745305, 21)

# %%
testdata.columns
# Out:
# Index(['id', 'MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors'],
#       dtype='object')

# %%
testdata.isna().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# dtype: int64

# %%
testdata.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  7.453050e+05     745305.000000       745305.000000    745305.000000
# mean   1.490609e+06          4.915610            4.930288         4.960027
# std    2.151512e+05          2.056295            2.094117         2.071722
# min    1.117957e+06          0.000000            0.000000         0.000000
# 25%    1.304283e+06          3.000000            3.000000         4.000000
# 50%    1.490609e+06          5.000000            5.000000         5.000000
# 75%    1.676935e+06          6.000000            6.000000         6.000000
# max    1.863261e+06         16.000000           17.000000        16.000000
#
#        Deforestation   Urbanization  ClimateChange    DamsQuality  \
# count  745305.000000  745305.000000  745305.000000  745305.000000
# mean        4.946084       4.938424       4.933524       4.958468
# std         2.052602       2.081816       2.059243       2.089312
# ...

# %%
testdata.head()
# Out:
#         id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0  1117957                 4                   6                3
# 1  1117958                 4                   4                2
# 2  1117959                 1                   3                6
# 3  1117960                 2                   4                4
# 4  1117961                 6                   3                2
#
#    Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0              5             6              7            8          7
# 1              9             5              5            4          7
# 2              5             7              2            4          6
# 3              6             4              5            4          3
# 4              4             6              4            5          5
#
#    AgriculturalPractices  ...  IneffectiveDisasterPreparedness  \
# 0                      8  ...                                8
# ...

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745305 entries, 0 to 745304
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               745305 non-null  int64
#  1   MonsoonIntensity                 745305 non-null  int64
#  2   TopographyDrainage               745305 non-null  int64
#  3   RiverManagement                  745305 non-null  int64
#  4   Deforestation                    745305 non-null  int64
#  5   Urbanization                     745305 non-null  int64
#  6   ClimateChange                    745305 non-null  int64
#  7   DamsQuality                      745305 non-null  int64
#  8   Siltation                        745305 non-null  int64
#  9   AgriculturalPractices            745305 non-null  int64
#  10  Encroachments                    745305 non-null  int64
#  11  IneffectiveDisasterPreparedness  745305 non-null  int64
# ...

# %% [markdown]
# # Test Data Visualization

# %%
nrows = (len(testdata.columns) + 2) // 3
ncols = min(len(testdata.columns), 3)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 5 * nrows))

if nrows == 1:
    axes = [axes]
elif ncols > 1:
    axes = axes.flatten()


for i, col in enumerate(testdata.columns):
    if col in ['id']:
        continue

    ax = axes[i]
    sns.histplot(testdata[col],bins=40, kde=True, ax=ax)
    ax.set_title(col + ' Distribution (Test Data)')
    ax.set_ylabel('Frequency')
    ax.set_xlabel(col)

features_to_plot = [col for col in testdata.columns if col not in ['id']]
if nrows * ncols > len(features_to_plot):
    for i in range(len(features_to_plot), nrows * ncols):
        fig.delaxes(axes[i])

plt.tight_layout()
plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4146630156.py in <cell line: 0>()
#      15
#      16     ax = axes[i]
# ---> 17     sns.histplot(testdata[col],bins=40, kde=True, ax=ax)
#      18     ax.set_title(col + ' Distribution (Test Data)')
#      19     ax.set_ylabel('Frequency')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 10))
sns.heatmap(testdata.corr(), annot=True,fmt='.2f', cmap='coolwarm', vmax=1, vmin=-1)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.title("Correlation Heatmap")
plt.show()
;
# Out:
# ''

# %% [markdown]
# # Interpretation of Results
# The analysis created above indicates that a linear relationship exists between several environmental and infrastructural factors and flood probability.
#
# The scatterplot showed a general overview. There are outliers visually, however, it is not enough to see the correlation and which specific factors contribute the most to flooding. To help visualize it on a narrower scale, the distribution graph was used to provide individual insights between frequency and each factor. The heatmap brought it altogether, as it helped narrow down which features are the strongest drivers of flooding by correlation.
#
# In summary, using the three data visualization techniques above, **MonsoonIntensity**, **TopographyDrainage**, **RiverManagement**, and **DeterioratingInfrastructure** show stronger positive correlations compared to other factors in the dataset. This indicates that the said factors contribute the most to the probability of flooding.

# %% [markdown]
# # Submission

# %%
# Re-define and fit the linear regression model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.85,random_state=0)

# %%
# Define features (X) and target (y)
X = train_data.drop(['id', 'FloodProbability'], axis=1) #features
y = train_data[['FloodProbability']] #target

# %%
sample_submission_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/sample_submission.csv?raw=true'

samplefile = pd.read_csv(sample_submission_url)

id = samplefile.pop('id')

# Remove the 'id' column from testdata
testdata_features = testdata.drop('id', axis=1)

y_pred = lr.predict(testdata_features)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'FloodProbability': y_pred.flatten() # Flatten the prediction array to match the shape of 'id'
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
